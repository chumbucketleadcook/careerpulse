# %%
# CareerPulse initial commit

# %%
# %sql
-- confirm we are connected to the correct catalog (workspace)
USE CATALOG "workspace";

# %%
# %sql
-- create new schemas for each layer of data: bronze/silver/gold/inference
CREATE SCHEMA IF NOT EXISTS careerpulse_bronze;
CREATE SCHEMA IF NOT EXISTS careerpulse_silver;
CREATE SCHEMA IF NOT EXISTS careerpulse_gold;
CREATE SCHEMA IF NOT EXISTS careerpulse_inference;

# %%
# %sql
--create the saved_queries table (in careerpulse_gold schema)
CREATE TABLE IF NOT EXISTS workspace.careerpulse_gold.saved_queries (
  query_id  STRING,
  query_title STRING,
  query_pattern STRING,
  is_active BOOLEAN,
  created_at TIMESTAMP
)

# %%
# %sql
SELECT * FROM workspace.careerpulse_gold.saved_queries;

# %%
# %sql
-- prevent the silver table from taking on new rows without job_id
  -- throws an error when previously run already

-- ALTER TABLE workspace.careerpulse_silver.job_postings_raw
-- ADD CONSTRAINT posting_id_not_null CHECK (posting_id IS NOT NULL);

# %%
# %sql
SHOW SCHEMAS;

# %%
# %sql
SELECT current_catalog() AS catalog, current_schema() AS schema;
